# %% [markdown]
# # Run this project in Google Colab
#
# This page is the **front door** for course use (students and instructor): run everything in a browser with a Google account instead of installing Python and GPU drivers locally. Each link below opens that notebook on Colab (the free GPU tier is enough for smaller runs, though full training can still take a while).
#
# **Important:** this repository holds **code and notebooks**, not the raw DementiaBank-style audio. You still need interview WAVs and metadata on **Google Drive** (or change paths in `config.py`). If you already work with the upstream DementiaNet layout, point `BASE_DIR` in `config.py` at that folder.
#
# ### One stable entry link (share this)
#
# Send people here first, then they follow the numbered steps:
#
# - **This notebook:** [Open `Colab_start_here` on Colab](https://colab.research.google.com/github/Msmetamorphosis/NeuralNets_Project_DementiaNet/blob/main/notebooks/Colab_start_here.ipynb)
#
# _If that link 404s, the branch might not be `main` yet — open the same file on GitHub, click the Colab icon, or swap `main` for your branch name in the URL._

# %% [markdown]
# ## How Colab finds your code
#
# The training notebooks use:
#
# - `drive.mount(...)`
# - `%cd /content/drive/MyDrive/NeuralNets_Project_DementiaNet` (or similar)
#
# So the **easiest demo path** is: clone or copy this repo onto Drive at that path, then open the step notebooks from that folder in Colab (or use the links below after mounting — you may need to **upload** a notebook copy into the mounted Drive folder so `%cd` and `config.py` line up).
#
# **Alternative:** clone into `/content` with git (next cell). You will still need audio under the paths in `config.py` (usually on Drive), so you still mount Drive for data even if the code lives in `/content`.

# %%
# Optional: pull latest code into Colab /content (does not replace Drive data)
# !pip install -q transformers datasets accelerate torchaudio evaluate scikit-learn pandas matplotlib huggingface_hub
# import os
# REPO = "NeuralNets_Project_DementiaNet"
# if not os.path.isdir(REPO):
#     !git clone https://github.com/Msmetamorphosis/NeuralNets_Project_DementiaNet.git
# %cd {REPO}
# print("Now in:", os.getcwd())

# %% [markdown]
# ## Scientific baseline (recommended order)
#
# | Step | Open in Colab |
# |------|----------------|
# | 0 – First pass dataset build | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Msmetamorphosis/NeuralNets_Project_DementiaNet/blob/main/notebooks/scientifically_valid_baseline/00_build_scientific_dataset.ipynb) |
# | 1 – Finalize manifests (30 s clips) | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Msmetamorphosis/NeuralNets_Project_DementiaNet/blob/main/notebooks/scientifically_valid_baseline/01_finalize_validated_dataset.ipynb) |
# | 2 – Train baseline Wav2Vec2 | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Msmetamorphosis/NeuralNets_Project_DementiaNet/blob/main/notebooks/scientifically_valid_baseline/02_train_scientific_baseline.ipynb) |
#
# ## SpecAugment experiment
#
# | Step | Open in Colab |
# |------|----------------|
# | Train with SpecAugment | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Msmetamorphosis/NeuralNets_Project_DementiaNet/blob/main/notebooks/specaugment/02_train_scientific_specaugment.ipynb) |
#
# ## Compare runs
#
# | Step | Open in Colab |
# |------|----------------|
# | Baseline vs SpecAugment metrics | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Msmetamorphosis/NeuralNets_Project_DementiaNet/blob/main/notebooks/specaugment/03_compare_baseline_vs_specaugment.ipynb) |

# %% [markdown]
# ## Tips for a smooth demo
#
# - Run **0 → 1** once per data refresh; manifests land under `clean_dataset` relative to `BASE_DIR` in `config.py`.
# - Before **2**, confirm `TRAIN_MANIFEST` / `VALID_MANIFEST` / `TEST_MANIFEST` paths exist.
# - Hugging Face **login** cells only matter if you `push_to_hub`.
# - For the comparison notebook, export `baseline_test_metrics.json` and `specaugment_test_metrics.json` into `results/` as described in those notebooks.
